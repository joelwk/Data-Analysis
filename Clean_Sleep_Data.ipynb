# %%
import pandas as  pd
import numpy as np

# %%
sleep = pd.read_csv('Organized_Sleep_Data.csv')

# %% [markdown]
# ### Preview first 10 rows of data and display data types

# %%
sleep.head(10)
# Out:
#            Start Time           End Time  Minutes Asleep  Minutes Awake  \
# 0   2020-01-01 1:16AM  2020-01-01 8:28AM             334             98
# 1  2020-01-01 11:00PM  2020-01-02 7:27AM             414             93
# 2  2020-01-02 11:03PM  2020-01-03 5:32AM             331             58
# 3   2020-01-03 8:53PM  2020-01-04 6:06AM             464             89
# 4   2020-01-04 8:55PM  2020-01-05 7:47AM             526            126
# 5  2020-01-05 10:11PM  2020-01-06 5:31AM             366             74
# 6   2020-01-06 8:47PM  2020-01-07 5:48AM             442             99
# 7  2020-01-07 11:19PM  2020-01-08 3:38AM             211             48
# 8   2020-01-08 9:51PM  2020-01-09 4:38AM             337             70
# 9  2020-01-09 10:55PM  2020-01-10 6:01AM             325            101
#
#    Number of Awakenings Time in Bed  Minutes REM Sleep  Minutes Light Sleep  \
# 0                    20         432               47.0                242.0
# 1                    33         507               50.0                346.0
# 2                    27         389               31.0                278.0
# 3                    36         553               84.0                341.0
# 4                    46         652               79.0                401.0
# 5                    23         440               59.0                262.0
# 6                    38         541               65.0                285.0
# 7                    15         259               36.0                138.0
# 8                    26         407               34.0                244.0
# 9                    26         426               29.0                270.0
#
#    Minutes Deep Sleep
# 0                45.0
# 1                18.0
# 2                22.0
# 3                39.0
# 4                46.0
# 5                45.0
# 6                92.0
# 7                37.0
# 8                59.0
# 9                26.0

# %%
sleep.dtypes
# Out:
# Start Time               object
# End Time                 object
# Minutes Asleep            int64
# Minutes Awake             int64
# Number of Awakenings      int64
# Time in Bed              object
# Minutes REM Sleep       float64
# Minutes Light Sleep     float64
# Minutes Deep Sleep      float64
# dtype: object

# %% [markdown]
# ### Converting the **Start and End Time** to datetime format

# %%
sleep['Start Time'] = pd.to_datetime(sleep['Start Time'])
sleep['End Time'] = pd.to_datetime(sleep['End Time'])

# %% [markdown]
# ### **Time in Bed** is still an object so we can convert that to a float, but we need to first replace the comma

# %%
sleep['Time in Bed'] = sleep['Time in Bed'].replace(',','', regex=True)
sleep['Time in Bed'] = sleep['Time in Bed'].astype(str).astype(int)

# %%
sleep.dtypes
# Out:
# Start Time              datetime64[ns]
# End Time                datetime64[ns]
# Minutes Asleep                   int64
# Minutes Awake                    int64
# Number of Awakenings             int64
# Time in Bed                      int32
# Minutes REM Sleep              float64
# Minutes Light Sleep            float64
# Minutes Deep Sleep             float64
# dtype: object

# %% [markdown]
# ### Check for any missing values

# %%
sleep[sleep.isnull().any(axis=1)]
# Out:
#              Start Time            End Time  Minutes Asleep  Minutes Awake  \
# 33  2020-02-02 09:20:00 2020-02-02 11:15:00             105             10
# 93  2020-04-02 11:30:00 2020-04-03 06:40:00             474            292
# 104 2020-04-13 04:22:00 2020-04-13 07:20:00             166             12
# 117 2020-04-28 05:28:00 2020-04-28 07:37:00             126              3
# 137 2020-05-18 22:54:00 2020-05-19 00:32:00              79             18
# 139 2020-05-20 00:34:00 2020-05-20 03:28:00             150             24
# 140 2020-05-20 05:37:00 2020-05-20 07:08:00              79             12
# 146 2020-05-26 03:42:00 2020-05-26 05:17:00              88              7
# 159 2020-06-10 09:39:00 2020-06-10 10:44:00              61              1
# 174 2020-06-23 22:47:00 2020-06-24 01:33:00             151             15
# 185 2020-07-05 02:58:00 2020-07-05 05:47:00             140             29
# 186 2020-07-05 22:58:00 2020-07-06 01:51:00             153             20
#
#      Number of Awakenings  Time in Bed  Minutes REM Sleep  \
# 33                      5          115                NaN
# 93                     64         1150                NaN
# 104                     1          178                NaN
# 117                     1          129                NaN
# 137                     4           97                NaN
# 139                     2          174                NaN
# 140                     1           91                NaN
# 146                     2           95                NaN
# 159                     0           65                NaN
# 174                     6          166                NaN
# 185                     3          169                NaN
# 186                     1          173                NaN
#
#      Minutes Light Sleep  Minutes Deep Sleep
# 33                   NaN                 NaN
# 93                   NaN                 NaN
# 104                  NaN                 NaN
# 117                  NaN                 NaN
# 137                  NaN                 NaN
# 139                  NaN                 NaN
# 140                  NaN                 NaN
# 146                  NaN                 NaN
# 159                  NaN                 NaN
# 174                  NaN                 NaN
# 185                  NaN                 NaN
# 186                  NaN                 NaN

# %% [markdown]
# ## Replace the missing data with respective column mean

# %%
for i in ['Minutes REM Sleep', 'Minutes Light Sleep', 'Minutes Deep Sleep']:
    sleep[i] = sleep[i].fillna(round(sleep[i].dropna().astype('float64').mean(),2))

# %% [markdown]
# Verify all missing data has been removed

# %%
sleep[sleep.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Start Time, End Time, Minutes Asleep, Minutes Awake, Number of Awakenings, Time in Bed, Minutes REM Sleep, Minutes Light Sleep, Minutes Deep Sleep]
# Index: []

# %%
sleep
# Out:
#              Start Time            End Time  Minutes Asleep  Minutes Awake  \
# 0   2020-01-01 01:16:00 2020-01-01 08:28:00             334             98
# 1   2020-01-01 23:00:00 2020-01-02 07:27:00             414             93
# 2   2020-01-02 23:03:00 2020-01-03 05:32:00             331             58
# 3   2020-01-03 20:53:00 2020-01-04 06:06:00             464             89
# 4   2020-01-04 20:55:00 2020-01-05 07:47:00             526            126
# ..                  ...                 ...             ...            ...
# 208 2020-07-26 22:14:00 2020-07-27 06:09:00             406             69
# 209 2020-07-28 00:26:00 2020-07-28 07:21:00             367             48
# 210 2020-07-28 22:13:00 2020-07-29 06:46:00             457             56
# 211 2020-07-29 22:24:00 2020-07-30 06:04:00             399             61
# 212 2020-07-31 00:06:00 2020-07-31 05:42:00             299             37
#
#      Number of Awakenings  Time in Bed  Minutes REM Sleep  \
# 0                      20          432               47.0
# 1                      33          507               50.0
# 2                      27          389               31.0
# 3                      36          553               84.0
# 4                      46          652               79.0
# ..                    ...          ...                ...
# 208                    24          475               89.0
# 209                    24          415               79.0
# 210                    28          513               99.0
# 211                    29          460               66.0
# 212                    26          336               51.0
#
#      Minutes Light Sleep  Minutes Deep Sleep
# 0                  242.0                45.0
# 1                  346.0                18.0
# 2                  278.0                22.0
# 3                  341.0                39.0
# 4                  401.0                46.0
# ..                   ...                 ...
# 208                264.0                53.0
# 209                237.0                51.0
# 210                267.0                91.0
# 211                289.0                44.0
# 212                234.0                14.0
#
# [213 rows x 9 columns]

# %% [markdown]
# ### **Save to CSV**

# %%
sleep.to_csv('Clean_Sleep_Data.csv', index=False)
